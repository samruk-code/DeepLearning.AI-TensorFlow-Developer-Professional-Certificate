# %% [markdown]
# # Week 1 Assignment: Housing Prices
#
# In this exercise you'll build a neural network that predicts the price of a house according to a simple formula.
#
# Imagine that house pricing is as easy as:
#
# A house has a base cost of 50k, and every additional bedroom adds a cost of 50k. This will make a 1 bedroom house cost 100k, a 2 bedroom house cost 150k etc.
#
# How would you create a neural network that learns this relationship so that it would predict a 7 bedroom house as costing close to 400k etc.
#
# Hint: Your network might work better if you scale the house price down. You don't have to give the answer 400...it might be better to create something that predicts the number 4, and then your answer is in the 'hundreds of thousands' etc.

# %% [markdown]
# #### TIPS FOR SUCCESSFUL GRADING OF YOUR ASSIGNMENT:
#
# - All cells are frozen except for the ones where you need to submit your solutions or when explicitly mentioned you can interact with it.
#
# - You can add new cells to experiment but these will be omitted by the grader, so don't rely on newly created cells to host your solution code, use the provided places for this.
#
# - You can add the comment # grade-up-to-here in any graded cell to signal the grader that it must only evaluate up to that point. This is helpful if you want to check if you are on the right track even if you are not done with the whole assignment. Be sure to remember to delete the comment afterwards!
#
# - Avoid using global variables unless you absolutely have to. The grader tests your code in an isolated environment without running all cells from the top. As a result, global variables may be unavailable when scoring your submission. Global variables that are meant to be used will be defined in UPPERCASE.
#
# - To submit your notebook, save it and then click on the blue submit button at the beginning of the page.

# %%
import numpy as np
import tensorflow as tf

# %%
import unittests

# %% [markdown]
# ## Exercise 1: create_training_data
#
# Your first task is to create the data that your model will be trained on. Use the scenario presented at the top of this notebook where a 1-bedroom house costs 100k, and increases by 50k for each additional bedroom.
#
# To generate the training data (aka the features and the targets), you will use numpy to create a one-dimensional tensor with the number of bedrooms and another one-dimensional tensor with the corresponding price in hundreds of thousands of dollars (e.g. 1.0 means 100k). In this case, the number of bedrooms will be the features, which the network will try to map to the target of the prices. **These tensors (or numpy arrays) should have six elements which will be the values (number of bedrooms and price in hundreds of thousands) for houses with 1 up to 6 bedrooms**.
#
# **Hints**:
# - Even if the number of bedrooms can be thought of as an integer, define these values as floats to account for scenarios such as half a bedroom.
# - The price should also be a float since currency is tipically defined as such.

# %%
# GRADED FUNCTION: create_training_data

def create_training_data():
    """Creates the data that will be used for training the model.

    Returns:
        (numpy.ndarray, numpy.ndarray): Arrays that contain info about the number of bedrooms and price in hundreds of thousands for 6 houses.
    """
    
    ### START CODE HERE ###    
    # Define feature and target tensors with the values for houses with 1 up to 6 bedrooms. 
    # For this exercise, please arrange the values in ascending order (i.e. 1, 2, 3, and so on).
    # Hint: Remember to explictly set the dtype as float when defining the numpy arrays
    n_bedrooms = np.array([1, 2, 3, 4, 5, 6], dtype = float)
    price_in_hundreds_of_thousands = np.array([1.0, 1.5, 2.0, 2.5, 3.0, 3.5], dtype = float)
    ### END CODE HERE ###

    return n_bedrooms, price_in_hundreds_of_thousands

# %%
features, targets = create_training_data()

print(f"Features have shape: {features.shape}")
print(f"Targets have shape: {targets.shape}")
# Out:
# Features have shape: (6,)
# Targets have shape: (6,)

# %% [markdown]
# **Expected Output:**
#
# ```
# Features have shape: (6,)
# Targets have shape: (6,)
# ```

# %%
# Test your code!
unittests.test_create_training_data(create_training_data)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 2: define_and_compile_model
#
# Your second task is to define the architecture of your model and compile it.
#
# For this particular task your model should be made up of a **single dense layer with 1 unit** and when compiling it, use:
#  - `Stochastic Gradient Descent` as the optimizer
#  - `Mean Squared Error` as the loss function
#
# **Remember that the training data is one-dimensional, so use this information when defining the shape of the Input**.
#
# In case you need some extra help, be sure to check the docs for [tf.keras.Input](https://www.tensorflow.org/api_docs/python/tf/keras/Input) and [tf.keras.layers.Dense](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense)

# %%
# GRADED FUNCTION: define_and_compile_model

def define_and_compile_model():
    """Returns the compiled (but untrained) model.

    Returns:
        tf.keras.Model: The model that will be trained to predict house prices.
    """
    
    ### START CODE HERE ###

    # Define your model
    model = tf.keras.Sequential([ 
		# Define the Input with the appropriate shape
		tf.keras.Input(shape = (1,)),
		# Define the Dense layer
		tf.keras.layers.Dense(units = 1)
	]) 
    
    # Compile your model
    model.compile(optimizer="sgd", loss="mean_squared_error")

    ### END CODE HERE ###

    return model

# %%
untrained_model = define_and_compile_model()

untrained_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1)              │             2 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2 (8.00 B)
#  Trainable params: 2 (8.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# **Expected Output:**
#
# ```
# Model: "sequential"
#
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1)              │             2 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#
# Total params: 2 (8.00 B)
#
# Trainable params: 2 (8.00 B)
#
# Non-trainable params: 0 (0.00 B)
# ```

# %%
# Test your code!
unittests.test_define_and_compile_model(define_and_compile_model)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 3: train_model
#
# With your model and the training data ready now it is time to train your model. You will feed this training data into the model so it can learn the relationship between the number of bedrooms and the price of the houses. For this you will use Tensorflow model's [fit](https://www.tensorflow.org/api_docs/python/tf/keras/Model#fit) method.
#
# After training you will test your network with a 7-bedroom house to see if it is able to accurately predict its price.

# %%
# GRADED FUNCTION: train_model

def train_model():
    """Returns the trained model.

    Returns:
        tf.keras.Model: The trained model that will predict house prices.
    """

    ### START CODE HERE ###

    # Define feature and target tensors with the values for houses with 1 up to 6 bedrooms
    # Hint: Remember you already coded a function that does this!
    n_bedrooms, price_in_hundreds_of_thousands = create_training_data()
    
    # Define a compiled (but untrained) model
    # Hint: Remember you already coded a function that does this!
    model = define_and_compile_model()
    
    # Train your model for 500 epochs by feeding the training data
    model.fit(n_bedrooms, price_in_hundreds_of_thousands, epochs=500)
    
    ### END CODE HERE ###

    return model

# %% [markdown]
# Now that you have a function that returns a compiled and trained model when invoked, use it to get the model to predict the price of houses:

# %%
# Get your trained model
trained_model = train_model()
# Out:
# Epoch 1/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 71.9395
# Epoch 2/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 33.2958
# Epoch 3/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 15.4103
# Epoch 4/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.1324
# Epoch 5/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.3011
# Epoch 6/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5279
# Epoch 7/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7072
# Epoch 8/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3273
# Epoch 9/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1515
# Epoch 10/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0702
# Epoch 11/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0325
# Epoch 12/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0151
# Epoch 13/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0070
# Epoch 14/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0033
# Epoch 15/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0015
# Epoch 16/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.4166e-04
# Epoch 17/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.7110e-04
# Epoch 18/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9940e-04
# Epoch 19/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.1972e-04
# Epoch 20/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.2649e-05
# Epoch 21/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.5291e-05
# Epoch 22/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.7060e-05
# Epoch 23/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.3055e-05
# Epoch 24/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.1008e-05
# Epoch 25/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.9867e-05
# Epoch 26/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.9148e-05
# Epoch 27/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8625e-05
# Epoch 28/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8195e-05
# Epoch 29/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.7808e-05
# Epoch 30/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.7443e-05
# Epoch 31/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.7090e-05
# Epoch 32/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6743e-05
# Epoch 33/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6401e-05
# Epoch 34/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6063e-05
# Epoch 35/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.5727e-05
# Epoch 36/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.5393e-05
# Epoch 37/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.5063e-05
# Epoch 38/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.4734e-05
# Epoch 39/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.4409e-05
# Epoch 40/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.4085e-05
# Epoch 41/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.3764e-05
# Epoch 42/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.3445e-05
# Epoch 43/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.3128e-05
# Epoch 44/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2814e-05
# Epoch 45/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2502e-05
# Epoch 46/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2192e-05
# Epoch 47/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.1885e-05
# Epoch 48/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.1580e-05
# Epoch 49/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.1277e-05
# Epoch 50/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.0976e-05
# Epoch 51/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.0678e-05
# Epoch 52/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.0381e-05
# Epoch 53/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.0087e-05
# Epoch 54/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.9795e-05
# Epoch 55/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.9505e-05
# Epoch 56/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.9217e-05
# Epoch 57/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.8932e-05
# Epoch 58/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.8648e-05
# Epoch 59/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.8366e-05
# Epoch 60/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8087e-05
# Epoch 61/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.7809e-05
# Epoch 62/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.7534e-05
# Epoch 63/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.7260e-05
# Epoch 64/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.6989e-05
# Epoch 65/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.6720e-05
# Epoch 66/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.6452e-05
# Epoch 67/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.6186e-05
# Epoch 68/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.5923e-05
# Epoch 69/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.5662e-05
# Epoch 70/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.5401e-05
# Epoch 71/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.5143e-05
# Epoch 72/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.4888e-05
# Epoch 73/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.4633e-05
# Epoch 74/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.4381e-05
# Epoch 75/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.4131e-05
# Epoch 76/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.3881e-05
# Epoch 77/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.3635e-05
# Epoch 78/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.3390e-05
# Epoch 79/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.3147e-05
# Epoch 80/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.2905e-05
# Epoch 81/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.2666e-05
# Epoch 82/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.2427e-05
# Epoch 83/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.2191e-05
# Epoch 84/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.1957e-05
# Epoch 85/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.1724e-05
# Epoch 86/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.1492e-05
# Epoch 87/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.1263e-05
# Epoch 88/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.1036e-05
# Epoch 89/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.0809e-05
# Epoch 90/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0585e-05
# Epoch 91/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0362e-05
# Epoch 92/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.0141e-05
# Epoch 93/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.9921e-05
# Epoch 94/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.9703e-05
# Epoch 95/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.9486e-05
# Epoch 96/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.9272e-05
# Epoch 97/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.9059e-05
# Epoch 98/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.8847e-05
# Epoch 99/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8637e-05
# Epoch 100/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8428e-05
# Epoch 101/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.8221e-05
# Epoch 102/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8015e-05
# Epoch 103/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7811e-05
# Epoch 104/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7609e-05
# Epoch 105/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7407e-05
# Epoch 106/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7208e-05
# Epoch 107/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.7010e-05
# Epoch 108/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.6813e-05
# Epoch 109/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.6618e-05
# Epoch 110/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6424e-05
# Epoch 111/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.
500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.6156e-06
# Epoch 383/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.5893e-06
# Epoch 384/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5630e-06
# Epoch 385/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.5372e-06
# Epoch 386/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.5115e-06
# Epoch 387/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4859e-06
# Epoch 388/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.4604e-06
# Epoch 389/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4353e-06
# Epoch 390/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.4102e-06
# Epoch 391/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.3855e-06
# Epoch 392/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.3607e-06
# Epoch 393/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.3362e-06
# Epoch 394/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3119e-06
# Epoch 395/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2879e-06
# Epoch 396/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.2639e-06
# Epoch 397/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.2401e-06
# Epoch 398/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.2166e-06
# Epoch 399/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.1930e-06
# Epoch 400/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.1699e-06
# Epoch 401/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.1467e-06
# Epoch 402/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.1239e-06
# Epoch 403/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.1009e-06
# Epoch 404/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0784e-06
# Epoch 405/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0560e-06
# Epoch 406/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0338e-06
# Epoch 407/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0116e-06
# Epoch 408/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.9896e-06
# Epoch 409/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.9680e-06
# Epoch 410/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.9463e-06
# Epoch 411/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9249e-06
# Epoch 412/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.9034e-06
# Epoch 413/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8824e-06
# Epoch 414/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8614e-06
# Epoch 415/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8406e-06
# Epoch 416/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8198e-06
# Epoch 417/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7992e-06
# Epoch 418/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7789e-06
# Epoch 419/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7587e-06
# Epoch 420/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.7386e-06
# Epoch 421/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7186e-06
# Epoch 422/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6989e-06
# Epoch 423/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6792e-06
# Epoch 424/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6597e-06
# Epoch 425/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6404e-06
# Epoch 426/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6209e-06
# Epoch 427/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.6018e-06
# Epoch 428/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.5830e-06
# Epoch 429/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5641e-06
# Epoch 430/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5455e-06
# Epoch 431/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5270e-06
# Epoch 432/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5085e-06
# Epoch 433/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4903e-06
# Epoch 434/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4722e-06
# Epoch 435/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4541e-06
# Epoch 436/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.4362e-06
# Epoch 437/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4185e-06
# Epoch 438/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4007e-06
# Epoch 439/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.3833e-06
# Epoch 440/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.3660e-06
# Epoch 441/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.3486e-06
# Epoch 442/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.3316e-06
# Epoch 443/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.3145e-06
# Epoch 444/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2977e-06
# Epoch 445/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2810e-06
# Epoch 446/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2644e-06
# Epoch 447/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2478e-06
# Epoch 448/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2315e-06
# Epoch 449/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2153e-06
# Epoch 450/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1991e-06
# Epoch 451/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1831e-06
# Epoch 452/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1672e-06
# Epoch 453/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1513e-06
# Epoch 454/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1357e-06
# Epoch 455/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1203e-06
# Epoch 456/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1048e-06
# Epoch 457/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0895e-06
# Epoch 458/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.0741e-06
# Epoch 459/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.0591e-06
# Epoch 460/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0441e-06
# Epoch 461/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0293e-06
# Epoch 462/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0143e-06
# Epoch 463/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9998e-06
# Epoch 464/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9851e-06
# Epoch 465/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9707e-06
# Epoch 466/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9563e-06
# Epoch 467/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9420e-06
# Epoch 468/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9280e-06
# Epoch 469/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9138e-06
# Epoch 470/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9000e-06
# Epoch 471/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8862e-06
# Epoch 472/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8723e-06
# Epoch 473/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8588e-06
# Epoch 474/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8452e-06
# Epoch 475/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8317e-06
# Epoch 476/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8183e-06
# Epoch 477/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8052e-06
# Epoch 478/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7919e-06
# Epoch 479/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7789e-06
# Epoch 480/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7661e-06
# Epoch 481/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7532e-06
# Epoch 482/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7403e-06
# Epoch 483/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7276e-06
# Epoch 484/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7151e-06
# Epoch 485/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7026e-06
# Epoch 486/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6901e-06
# Epoch 487/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6778e-06
# Epoch 488/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.6656e-06
# Epoch 489/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6535e-06
# Epoch 490/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6414e-06
# Epoch 491/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6296e-06
# Epoch 492/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6176e-06
# Epoch 493/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6059e-06
# Epoch 494/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5941e-06
# Epoch 495/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5826e-06
# Epoch 496/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5711e-06
# Epoch 497/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5595e-06
# Epoch 498/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5482e-06
# Epoch 499/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5369e-06
# Epoch 500/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5257e-06

# %% [markdown]
# **Expected Output:**
#
# Values of loss function don't need to be exact to these values
#
# ```
# Epoch 1/500
# 1/1 [==============================] - 0s 409ms/step - loss: 14.7905
# Epoch 2/500
# 1/1 [==============================] - 0s 5ms/step - loss: 6.8536
# Epoch 3/500
# 1/1 [==============================] - 0s 7ms/step - loss: 3.1801
# ...
# ...
# ...
# 1/1 [==============================] - 0s 12ms/step - loss: 1.0113e-07
# Epoch 500/500
# 1/1 [==============================] - 0s 12ms/step - loss: 1.0038e-07
# ```

# %% [markdown]
# Now that your model has finished training it is time to test it out! You can do so by running the next cell.

# %%
new_n_bedrooms = np.array([7.0])
predicted_price = trained_model.predict(new_n_bedrooms, verbose=False).item()
print(f"Your model predicted a price of {predicted_price:.2f} hundreds of thousands of dollars for a {int(new_n_bedrooms.item())} bedrooms house")
# Out:
# Your model predicted a price of 4.00 hundreds of thousands of dollars for a 7 bedrooms house

# %% [markdown]
# **Expected Output:**
#
# Values of loss function don't need to be exact to these values
#
# ```
# Your model predicted a price of 4.03 hundreds of thousands of dollars for a 7 bedrooms house
# ```
#
# **The price doesn't need to exactly match this one but it should be close to 4.**

# %%
# Test your code!
unittests.test_trained_model(trained_model)
# Out:
#  All tests passed!

# %% [markdown]
# If everything went as expected you should see a prediction value very close to 4. **If not, try adjusting your code before submitting the assignment.** Notice that you can play around with the value of `new_n_bedrooms` to get different predictions. In general you should see that the network was able to learn the linear relationship between `n_bedrooms` and `price_in_hundreds_of_thousands`, so if you use a value of 8.0 you should get a prediction close to 4.5 and so on.

# %% [markdown]
# **Congratulations on finishing this week's assignment!**
#
# You have successfully coded a neural network that learned the linear relationship between two variables. Nice job!
#
# **Keep it up!**
